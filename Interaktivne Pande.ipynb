# %%
import pandas as pd

# %%
from Pandas_functions impmort *
# Out:
#   File "<ipython-input-2-54de5d3d9333>", line 1
#     from Pandas_functions impmort *
#                                 ^
# SyntaxError: invalid syntax

# %%
from Pandas_functions import *

# %%
funtion1()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-edb0abd612f7> in <module>()
# ----> 1 funtion1()
#
# NameError: name 'funtion1' is not defined

# %%
function1()
# Out:
# Hello, pandas!

# %%
zapis = pd.read_csv('../podatki_za_obdelavo')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-4358757ee8bc> in <module>()
# ----> 1 zapis = pd.read_csv('../podatki_za_obdelavo')
#
# D:\nanaconda\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
# ...

# %%
zapis = pd.read_csv('../podatki_za_obdelavo.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-2999f1ba0bb9> in <module>()
# ----> 1 zapis = pd.read_csv('../podatki_za_obdelavo.csv')
#
# D:\nanaconda\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
# ...

# %%
zapis = pd.read_csv('podatki_za_obdelavo')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-0fe7219fe739> in <module>()
# ----> 1 zapis = pd.read_csv('podatki_za_obdelavo')
#
# D:\nanaconda\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
# ...

# %%
zapis = pd.read_csv('podatki_za_obdelavo.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-376b00be04b4> in <module>()
# ----> 1 zapis = pd.read_csv('podatki_za_obdelavo.csv')
#
# D:\nanaconda\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
# ...

# %%
zapis = pd.read_csv('podatki_za_obdelavo')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-0fe7219fe739> in <module>()
# ----> 1 zapis = pd.read_csv('podatki_za_obdelavo')
#
# D:\nanaconda\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
# ...

# %%
zapis = pd.read_csv('../podatki_za_obdelavo')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-4358757ee8bc> in <module>()
# ----> 1 zapis = pd.read_csv('../podatki_za_obdelavo')
#
# D:\nanaconda\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
# ...

# %%
zapis = pd.read_csv('podatki_za_obdelavo.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-376b00be04b4> in <module>()
# ----> 1 zapis = pd.read_csv('podatki_za_obdelavo.csv')
#
# D:\nanaconda\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
# ...

# %%
zapis = pd.read_csv('../podatki_za_obdelavo.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-2999f1ba0bb9> in <module>()
# ----> 1 zapis = pd.read_csv('../podatki_za_obdelavo.csv')
#
# D:\nanaconda\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
# ...

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
pd.set_option('display.mpl_style', 'default'
# Out:
#   File "<ipython-input-16-98791d7c2922>", line 1
#     pd.set_option('display.mpl_style', 'default'
#                                                 ^
# SyntaxError: unexpected EOF while parsing

# %%
pd.set_option('display.mpl_style', 'default')
# Out:
# D:\nanaconda\lib\site-packages\IPython\core\interactiveshell.py:2862: FutureWarning:
# mpl_style had been deprecated and will be removed in a future version.
# Use `matplotlib.pyplot.style.use` instead.
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
matplotlib.pyplot.style.use
# Out:
#   File "<ipython-input-18-61ef56e48f8e>", line 1
#     plt.pyplot.style.use('display.mpl_style', 'default'
#                                                        ^
# SyntaxError: unexpected EOF while parsing

# %%
matplotlib.pyplot.style.use('display.mpl_style', 'default')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-25bc70eb5f05> in <module>()
# ----> 1 matplotlib.pyplot.style.use('display.mpl_style', 'default')
#
# NameError: name 'matplotlib' is not defined

# %%
plt.pyplot.style.use('display.mpl_style', 'default')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-aa0430d5106f> in <module>()
# ----> 1 plt.pyplot.style.use('display.mpl_style', 'default')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'pyplot'

# %%
matplotlib.style.use('display.mpl_style', 'default')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-25bed3e67b8c> in <module>()
# ----> 1 matplotlib.style.use('display.mpl_style', 'default')
#
# NameError: name 'matplotlib' is not defined

# %%
plt.style.use('display.mpl_style', 'default')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-cc110ad98cf7> in <module>()
# ----> 1 plt.style.use('display.mpl_style', 'default')
#
# TypeError: use() takes 1 positional argument but 2 were given

# %%
plt.style.use('display.mpl_style'')
# Out:
#   File "<ipython-input-23-90e0097c6934>", line 1
#     plt.style.use('display.mpl_style'')
#                                        ^
# SyntaxError: EOL while scanning string literal

# %%
plt.style.use('display.mpl_style')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# D:\nanaconda\lib\site-packages\matplotlib\style\core.py in use(style)
#     112             try:
# --> 113                 rc = rc_params_from_file(style, use_default_template=False)
#     114                 _apply_style(rc)
#
# D:\nanaconda\lib\site-packages\matplotlib\__init__.py in rc_params_from_file(fname, fail_on_error, use_default_template)
#    1028     """
# -> 1029     config_from_file = _rc_params_in_file(fname, fail_on_error)
#    1030
#
# D:\nanaconda\lib\site-packages\matplotlib\__init__.py in _rc_params_in_file(fname, fail_on_error)
#     944     rc_temp = {}
# --> 945     with _open_file_or_url(fname) as fd:
#     946         try:
#
# D:\nanaconda\lib\contextlib.py in __enter__(self)
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#
# ...

# %%
print(podatki)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-8c0cd4f670d5> in <module>()
# ----> 1 print(podatki)
#
# NameError: name 'podatki' is not defined

# %%
from Pandas_functions import *

# %%
podatki
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-7508797a11b9> in <module>()
# ----> 1 podatki
#
# NameError: name 'podatki' is not defined

# %%
print(podatki)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-8c0cd4f670d5> in <module>()
# ----> 1 print(podatki)
#
# NameError: name 'podatki' is not defined

# %%
function1()
# Out:
# Hello, pandas!

# %%
zapis = pd.read_csv(podatki)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-f4a5ca72b95a> in <module>()
# ----> 1 zapis = pd.read_csv(podatki)
#
# NameError: name 'podatki' is not defined

# %%
from Pandas_functions import *

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-60b725f10c9c> in <module>()
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
from Pandas_functions as panda import *
# Out:
#   File "<ipython-input-34-45f0051300ad>", line 1
#     from Pandas_functions as panda import *
#                            ^
# SyntaxError: invalid syntax

# %%
from Pandas_functions import a
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-35-cd8ee00e2514> in <module>()
# ----> 1 from Pandas_functions import a
#
# ImportError: cannot import name 'a'

# %%
zapis = pd.read_csv('C:\Users\Kristjan\Documents\GitHub\ProjectTennis\odatki_za_obdelavo')
# Out:
#   File "<ipython-input-36-53ac54df6d4e>", line 1
#     zapis = pd.read_csv('C:\Users\Kristjan\Documents\GitHub\ProjectTennis\odatki_za_obdelavo')
#                        ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
zapis = pd.read_csv ('C:\Users\Kristjan\Documents\GitHub\ProjectTennis\odatki_za_obdelavo')
# Out:
#   File "<ipython-input-37-06bd8f002527>", line 1
#     zapis = pd.read_csv ('C:\Users\Kristjan\Documents\GitHub\ProjectTennis\odatki_za_obdelavo')
#                         ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
zapis = pd.read_csv('C:\Users\Kristjan\Documents\GitHub\ProjectTennis\odatki_za_obdelavo', encoding = 'utf-8')
# Out:
#   File "<ipython-input-38-62ae33c0cb44>", line 1
#     zapis = pd.read_csv('C:\Users\Kristjan\Documents\GitHub\ProjectTennis\odatki_za_obdelavo', encoding = 'utf-8')
#                        ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
zapis = pd.read_csv('C:\Users\Kristjan\Documents\GitHub\ProjectTennis\podatki_za_obdelavo', encoding = 'utf-8')
# Out:
#   File "<ipython-input-39-3d874439bc38>", line 1
#     zapis = pd.read_csv('C:\Users\Kristjan\Documents\GitHub\ProjectTennis\podatki_za_obdelavo', encoding = 'utf-8')
#                        ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
zapis = pd.read_csv(r'C:\Users\Kristjan\Documents\GitHub\ProjectTennis\podatki_za_obdelavo', encoding = 'utf-8')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-40-d70c2cdd1b25> in <module>()
# ----> 1 zapis = pd.read_csv(r'C:\Users\Kristjan\Documents\GitHub\ProjectTennis\podatki_za_obdelavo', encoding = 'utf-8')
#
# ...

# %%
zapis = pd.read_csv('C:\Users\Kristjan\Documents\GitHub\ProjectTennis\podatki_za_obdelavo.txt', encoding = 'utf-8')
# Out:
#   File "<ipython-input-41-0de714f54481>", line 1
#     zapis = pd.read_csv('C:\Users\Kristjan\Documents\GitHub\ProjectTennis\podatki_za_obdelavo.txt', encoding = 'utf-8')
#                        ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
zapis = pd.read_csv(r'C:\Users\Kristjan\Documents\GitHub\ProjectTennis\podatki_za_obdelavo.txt', encoding = 'utf-8')

# %%
print(zapis)
# Out:
#      Rafael Nadal: 1; ESP; 31; 1986.06.03; 85; 185; 67-11; 6; 15  \
# 0     Roger Federer: 2; SUI; 36; 1981.08.08; 85; 185...
# 1     Grigor Dimitrov: 3; BUL; 26; 1991.05.16; 80; 1...
# 2     Alexander Zverev: 4; GER; 20; 1997.04.20; 86; ...
# 3     Dominic Thiem: 5; AUT; 24; 1993.09.03; 82; 185...
# 4     Marin Cilic: 6; CRO; 29; 1988.09.28; 89; 198; ...
# 5     David Goffin: 7; BEL; 27; 1990.12.07; 68; 180;...
# 6     Jack Sock: 8; USA; 25; 1992.09.24; 84; 191; 38...
# 7     Stan Wawrinka: 9; SUI; 32; 1985.03.28; 81; 183...
# 8     Pablo Carreno Busta: 10; ESP; 26; 1991.07.12; ...
# 9     Juan Martin del Potro: 11; ARG; 29; 1988.09.23...
# 10    Novak Djokovic: 12; SRB; 30; 1987.05.22; 77; 1...
# 11    Sam Querrey: 13; USA; 30; 1987.10.07; 95; 198;...
# 12    Kevin Anderson: 14; RSA; 31; 1986.05.18; 93; 2...
# 13    Jo-Wilfried Tsonga: 15; FRA; 32; 1985.04.17; 9...
# 14    Andy Murray: 16; GBR; 30; 1987.05.15; 84; 191;...
# 15    John Isner: 17; USA; 32; 1985.04.26; 108; 208;...
# ...

# %%
zapis[3:]
# Out:
#      Rafael Nadal: 1; ESP; 31; 1986.06.03; 85; 185; 67-11; 6; 15  \
# 3     Dominic Thiem: 5; AUT; 24; 1993.09.03; 82; 185...
# 4     Marin Cilic: 6; CRO; 29; 1988.09.28; 89; 198; ...
# 5     David Goffin: 7; BEL; 27; 1990.12.07; 68; 180;...
# 6     Jack Sock: 8; USA; 25; 1992.09.24; 84; 191; 38...
# 7     Stan Wawrinka: 9; SUI; 32; 1985.03.28; 81; 183...
# 8     Pablo Carreno Busta: 10; ESP; 26; 1991.07.12; ...
# 9     Juan Martin del Potro: 11; ARG; 29; 1988.09.23...
# 10    Novak Djokovic: 12; SRB; 30; 1987.05.22; 77; 1...
# 11    Sam Querrey: 13; USA; 30; 1987.10.07; 95; 198;...
# 12    Kevin Anderson: 14; RSA; 31; 1986.05.18; 93; 2...
# 13    Jo-Wilfried Tsonga: 15; FRA; 32; 1985.04.17; 9...
# 14    Andy Murray: 16; GBR; 30; 1987.05.15; 84; 191;...
# 15    John Isner: 17; USA; 32; 1985.04.26; 108; 208;...
# 16    Lucas Pouille: 18; FRA; 23; 1994.02.23; 81; 18...
# 17    Tomas Berdych: 19; CZE; 32; 1985.09.17; 91; 19...
# 18    Roberto Bautista Agut: 20; ESP; 29; 1988.04.14...
# ...

# %%
zapis[:3]
# Out:
#   Rafael Nadal: 1; ESP; 31; 1986.06.03; 85; 185; 67-11; 6; 15  851  \
# 0  Roger Federer: 2; SUI; 36; 1981.08.08; 85; 185...           054
# 1  Grigor Dimitrov: 3; BUL; 26; 1991.05.16; 80; 1...           575
# 2  Alexander Zverev: 4; GER; 20; 1997.04.20; 86; ...           006
#
#      340; 1; 873-185; 75; 94    588    627
# 0  856; 1; 1132-250; 95; 111  885.0  682.0
# 1     244; 3; 257-161; 8; 14   83.0  976.0
# 2       313; 3; 117-70; 6; 7   41.0  628.0

# %%
zapis[:3]
# Out:
#   Rafael Nadal: 1; ESP; 31; 1986.06.03; 85; 185; 67-11; 6; 15  851  \
# 0  Roger Federer: 2; SUI; 36; 1981.08.08; 85; 185...           054
# 1  Grigor Dimitrov: 3; BUL; 26; 1991.05.16; 80; 1...           575
# 2  Alexander Zverev: 4; GER; 20; 1997.04.20; 86; ...           006
#
#      340; 1; 873-185; 75; 94    588    627
# 0  856; 1; 1132-250; 95; 111  885.0  682.0
# 1     244; 3; 257-161; 8; 14   83.0  976.0
# 2       313; 3; 117-70; 6; 7   41.0  628.0

# %%
zapis = pd.read_csv(r'C:\Users\Kristjan\Documents\GitHub\ProjectTennis\podatki_za_obdelavo.txt', encoding = 'utf-8')

# %%
zapis[:3]
# Out:
#                                                                                         Ime; rank; country; age; birthday; wight(kg); height(cm); W-L 17; tournaments won 17; earnings 17; W-L career; tournaments won career; earnings career
# Rafael Nadal: 1; ESP; 31; 1986.06.03; 85; 185; ... 851 340; 1; 873-185; 75; 94   588.0                                              627.0
# Roger Federer: 2; SUI; 36; 1981.08.08; 85; 185;... 054 856; 1; 1132-250; 95; 111 885.0                                              682.0
# Grigor Dimitrov: 3; BUL; 26; 1991.05.16; 80; 19... 575 244; 3; 257-161; 8; 14    83.0                                               976.0

# %%
zapis = pd.read_csv(r'C:\Users\Kristjan\Documents\GitHub\ProjectTennis\podatki_za_obdelavo.txt', encoding = 'utf-8')
zapis[:3]
# Out:
#                                                                                         Name; rank; country; age; birthday; wight(kg); height(cm); W-L 17; tournaments won 17; earnings 17; W-L career; tournaments won career; earnings career
# Rafael Nadal: 1; ESP; 31; 1986.06.03; 85; 185; ... 851 340; 1; 873-185; 75; 94   588.0                                              627.0
# Roger Federer: 2; SUI; 36; 1981.08.08; 85; 185;... 054 856; 1; 1132-250; 95; 111 885.0                                              682.0
# Grigor Dimitrov: 3; BUL; 26; 1991.05.16; 80; 19... 575 244; 3; 257-161; 8; 14    83.0                                               976.0

# %%
zapis = pd.read_csv(r'C:\Users\Kristjan\Documents\GitHub\ProjectTennis\podatki_za_obdelavo.txt', encoding = 'utf-8', sep=';', parse_dates=['Date'], dayfirst=True, index_col='Date'))
zapis[:3]
# Out:
#   File "<ipython-input-50-10a3517deacd>", line 1
#     zapis = pd.read_csv(r'C:\Users\Kristjan\Documents\GitHub\ProjectTennis\podatki_za_obdelavo.txt', encoding = 'utf-8', sep=';', parse_dates=['Date'], dayfirst=True, index_col='Date'))
#                                                                                                                                                                                         ^
# SyntaxError: invalid syntax

# %%
zapis = pd.read_csv(r'C:\Users\Kristjan\Documents\GitHub\ProjectTennis\podatki_za_obdelavo.txt', encoding = 'utf-8',
                    sep=';', parse_dates=['Date'], dayfirst=True, index_col='Date')
zapis[:3]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-32b5e56d1a19> in <module>()
#       1 zapis = pd.read_csv(r'C:\Users\Kristjan\Documents\GitHub\ProjectTennis\podatki_za_obdelavo.txt', encoding = 'utf-8',
# ----> 2                     sep=';', parse_dates=['Date'], dayfirst=True, index_col='Date')
#       3 zapis[:3]
#
# ...

# %%
zapis = pd.read_csv(r'C:\Users\Kristjan\Documents\GitHub\ProjectTennis\podatki_za_obdelavo.txt', encoding = 'utf-8', sep=';')
zapis[:3]
# Out:
#                  Name  rank   country          age  birthday  wight(kg)  \
# 0     Rafael Nadal: 1   ESP        31   1986.06.03        85        185
# 1    Roger Federer: 2   SUI        36   1981.08.08        85        185
# 2  Grigor Dimitrov: 3   BUL        26   1991.05.16        80        191
#
#    height(cm)   W-L 17  tournaments won 17   earnings 17  W-L career  \
# 0       67-11        6          15,851,340             1     873-185
# 1        52-5        7          13,054,856             1    1132-250
# 2       49-19        4           6,575,244             3     257-161
#
#     tournaments won career  earnings career
# 0                       75        94,588,627
# 1                       95       111,885,682
# 2                        8        14,083,976

# %%
zapis = pd.read_csv(r'C:\Users\Kristjan\Documents\GitHub\ProjectTennis\podatki_za_obdelavo.txt', encoding = 'utf-8', sep=';')
zapis[:3]
# Out:
#                  Name  rank   country          age  birthday  wight(kg)  \
# Rafael Nadal        1   ESP        31   1986.06.03        85        185
# Roger Federer       2   SUI        36   1981.08.08        85        185
# Grigor Dimitrov     3   BUL        26   1991.05.16        80        191
#
#                  height(cm)   W-L 17  tournaments won 17   earnings 17  \
# Rafael Nadal          67-11        6          15,851,340             1
# Roger Federer          52-5        7          13,054,856             1
# Grigor Dimitrov       49-19        4           6,575,244             3
#
#                  W-L career   tournaments won career  earnings career
# Rafael Nadal        873-185                       75        94,588,627
# Roger Federer      1132-250                       95       111,885,682
# Grigor Dimitrov     257-161                        8        14,083,976

# %%
zapis = pd.read_csv(r'C:\Users\Kristjan\Documents\GitHub\ProjectTennis\podatki_za_obdelavo.txt', encoding = 'utf-8', sep=';')
zapis[:3]
# Out:
#                  Name  Rank   Country          Age  Birthday  Weight(kg)  \
# Rafael Nadal        1   ESP        31   1986.06.03        85         185
# Roger Federer       2   SUI        36   1981.08.08        85         185
# Grigor Dimitrov     3   BUL        26   1991.05.16        80         191
#
#                  Height(cm)   W-L 17  Tournaments won 17   Earnings 17  \
# Rafael Nadal          67-11        6          15,851,340             1
# Roger Federer          52-5        7          13,054,856             1
# Grigor Dimitrov       49-19        4           6,575,244             3
#
#                  W-L career   Tournaments won career  Earnings career
# Rafael Nadal        873-185                       75        94,588,627
# Roger Federer      1132-250                       95       111,885,682
# Grigor Dimitrov     257-161                        8        14,083,976

# %%
zapis = pd.read_csv(r'C:\Users\Kristjan\Documents\GitHub\ProjectTennis\podatki_za_obdelavo.txt', encoding = 'utf-8', sep=';')
zapis[:100]
# Out:
#                         Name  Rank   Country          Age  Birthday  \
# Rafael Nadal               1   ESP        31   1986.06.03        85
# Roger Federer              2   SUI        36   1981.08.08        85
# Grigor Dimitrov            3   BUL        26   1991.05.16        80
# Alexander Zverev           4   GER        20   1997.04.20        86
# Dominic Thiem              5   AUT        24   1993.09.03        82
# Marin Cilic                6   CRO        29   1988.09.28        89
# David Goffin               7   BEL        27   1990.12.07        68
# Jack Sock                  8   USA        25   1992.09.24        84
# Stan Wawrinka              9   SUI        32   1985.03.28        81
# Pablo Carreno Busta       10   ESP        26   1991.07.12        78
# Juan Martin del Potro     11   ARG        29   1988.09.23        97
# Novak Djokovic            12   SRB        30   1987.05.22        77
# Sam Querrey               13   USA        30   1987.10.07        95
# ...

# %%
zapis = pd.read_csv(r'C:\Users\Kristjan\Documents\GitHub\ProjectTennis\podatki_za_obdelavo.txt', encoding = 'utf-8', sep=';')
zapis[:3]
# Out:
#                    Rank   Country          Age  Birthday  Weight(kg)  \
# Rafael Nadal    1   ESP        31   1986.06.03        85         185
# Roger Federer   2   SUI        36   1981.08.08        85         185
# Grigor Dimitrov 3   BUL        26   1991.05.16        80         191
#
#                    Height(cm)   W-L 17  Tournaments won 17   Earnings 17  \
# Rafael Nadal    1       67-11        6          15,851,340             1
# Roger Federer   2        52-5        7          13,054,856             1
# Grigor Dimitrov 3       49-19        4           6,575,244             3
#
#                    W-L career   Tournaments won career  Earnings career
# Rafael Nadal    1     873-185                       75        94,588,627
# Roger Federer   2    1132-250                       95       111,885,682
# Grigor Dimitrov 3     257-161                        8        14,083,976

# %%
zapis = pd.read_csv(r'C:\Users\Kristjan\Documents\GitHub\ProjectTennis\podatki_za_obdelavo.txt', encoding = 'utf-8', sep=';')
zapis[:3]
# Out:
#                  Name  Rank   Country          Age  Birthday  Weight(kg)  \
# Rafael Nadal        1   ESP        31   1986.06.03        85         185
# Roger Federer       2   SUI        36   1981.08.08        85         185
# Grigor Dimitrov     3   BUL        26   1991.05.16        80         191
#
#                  Height(cm)   W-L 17  Tournaments won 17   Earnings 17  \
# Rafael Nadal          67-11        6          15,851,340             1
# Roger Federer          52-5        7          13,054,856             1
# Grigor Dimitrov       49-19        4           6,575,244             3
#
#                  W-L career   Tournaments won career  Earnings career
# Rafael Nadal        873-185                       75        94,588,627
# Roger Federer      1132-250                       95       111,885,682
# Grigor Dimitrov     257-161                        8        14,083,976

# %%
zapis = pd.read_csv(r'C:\Users\Kristjan\Documents\GitHub\ProjectTennis\podatki_za_obdelavo.txt', encoding = 'utf-8', sep=';')
zapis[:100]
# Out:
#                         Name  Rank   Country          Age  Birthday  \
# Rafael Nadal               1   ESP        31   1986.06.03        85
# Roger Federer              2   SUI        36   1981.08.08        85
# Grigor Dimitrov            3   BUL        26   1991.05.16        80
# Alexander Zverev           4   GER        20   1997.04.20        86
# Dominic Thiem              5   AUT        24   1993.09.03        82
# Marin Cilic                6   CRO        29   1988.09.28        89
# David Goffin               7   BEL        27   1990.12.07        68
# Jack Sock                  8   USA        25   1992.09.24        84
# Stan Wawrinka              9   SUI        32   1985.03.28        81
# Pablo Carreno Busta       10   ESP        26   1991.07.12        78
# Juan Martin del Potro     11   ARG        29   1988.09.23        97
# Novak Djokovic            12   SRB        30   1987.05.22        77
# Sam Querrey               13   USA        30   1987.10.07        95
# ...

# %%
zapis = pd.read_csv(r'C:\Users\Kristjan\Documents\GitHub\ProjectTennis\podatki_za_obdelavo.txt', encoding = 'utf-8', sep=';')
zapis[:100]
# Out:
#                         Unnamed: 0  Rank   Country          Age  Birthday  \
# Rafael Nadal                     1   ESP        31   1986.06.03        85
# Roger Federer                    2   SUI        36   1981.08.08        85
# Grigor Dimitrov                  3   BUL        26   1991.05.16        80
# Alexander Zverev                 4   GER        20   1997.04.20        86
# Dominic Thiem                    5   AUT        24   1993.09.03        82
# Marin Cilic                      6   CRO        29   1988.09.28        89
# David Goffin                     7   BEL        27   1990.12.07        68
# Jack Sock                        8   USA        25   1992.09.24        84
# Stan Wawrinka                    9   SUI        32   1985.03.28        81
# Pablo Carreno Busta             10   ESP        26   1991.07.12        78
# Juan Martin del Potro           11   ARG        29   1988.09.23        97
# Novak Djokovic                  12   SRB        30   1987.05.22        77
# ...

# %%
zapis = pd.read_csv(r'C:\Users\Kristjan\Documents\GitHub\ProjectTennis\podatki_za_obdelavo.txt', encoding = 'utf-8', sep=';')
zapis[:100]
# Out:
#                         Unnamed: 0  Rank   Country          Age  Birthday  \
# Rafael Nadal                     1   ESP        31   1986.06.03        85
# Roger Federer                    2   SUI        36   1981.08.08        85
# Grigor Dimitrov                  3   BUL        26   1991.05.16        80
# Alexander Zverev                 4   GER        20   1997.04.20        86
# Dominic Thiem                    5   AUT        24   1993.09.03        82
# Marin Cilic                      6   CRO        29   1988.09.28        89
# David Goffin                     7   BEL        27   1990.12.07        68
# Jack Sock                        8   USA        25   1992.09.24        84
# Stan Wawrinka                    9   SUI        32   1985.03.28        81
# Pablo Carreno Busta             10   ESP        26   1991.07.12        78
# Juan Martin del Potro           11   ARG        29   1988.09.23        97
# Novak Djokovic                  12   SRB        30   1987.05.22        77
# ...

# %%
zapis = pd.read_csv(r'C:\Users\Kristjan\Documents\GitHub\ProjectTennis\podatki_za_obdelavo.txt', encoding = 'utf-8', sep=';')
zapis[:100]
# Out:
#                             Rank   Country          Age  Birthday  Weight(kg)  \
# Rafael Nadal           1     ESP        31   1986.06.03        85         185
# Roger Federer          2     SUI        36   1981.08.08        85         185
# Grigor Dimitrov        3     BUL        26   1991.05.16        80         191
# Alexander Zverev       4     GER        20   1997.04.20        86         198
# Dominic Thiem          5     AUT        24   1993.09.03        82         185
# Marin Cilic            6     CRO        29   1988.09.28        89         198
# David Goffin           7     BEL        27   1990.12.07        68         180
# Jack Sock              8     USA        25   1992.09.24        84         191
# Stan Wawrinka          9     SUI        32   1985.03.28        81         183
# Pablo Carreno Busta    10    ESP        26   1991.07.12        78         188
# Juan Martin del Potro  11    ARG        29   1988.09.23        97         198
# ...

# %%
zapis = pd.read_csv(r'C:\Users\Kristjan\Documents\GitHub\ProjectTennis\podatki_za_obdelavo.txt', encoding = 'utf-8', sep=';')
zapis[:100]
# Out:
#                         Rank  Country   Age     Birthday  Weight(kg)  \
# Rafael Nadal               1      ESP    31   1986.06.03          85
# Roger Federer              2      SUI    36   1981.08.08          85
# Grigor Dimitrov            3      BUL    26   1991.05.16          80
# Alexander Zverev           4      GER    20   1997.04.20          86
# Dominic Thiem              5      AUT    24   1993.09.03          82
# Marin Cilic                6      CRO    29   1988.09.28          89
# David Goffin               7      BEL    27   1990.12.07          68
# Jack Sock                  8      USA    25   1992.09.24          84
# Stan Wawrinka              9      SUI    32   1985.03.28          81
# Pablo Carreno Busta       10      ESP    26   1991.07.12          78
# Juan Martin del Potro     11      ARG    29   1988.09.23          97
# Novak Djokovic            12      SRB    30   1987.05.22          77
# Sam Querrey               13      USA    30   1987.10.07          95
# ...

# %%
zapis = pd.read_csv(r'C:\Users\Kristjan\Documents\GitHub\ProjectTennis\podatki_za_obdelavo.txt', encoding = 'utf-8', sep=';')
zapis[-100:]
# Out:
#                              Rank  Country   Age     Birthday  Weight(kg)  \
# Kody Pearson                 1849      AUS    18   1999.07.26          60
# Minhtuan Pham                1849      VIE    24   1993.10.19           /
# Greg Polmans                 1849      AUS    17   2000.01.10           /
# Nino Portales                1849      FRA    21   1996.12.28           /
# Yusuf Ebrahim Ahmed  Qaed    1849      BRN    23   1994.07.15           /
# Mauricio Resendiz            1849      MEX    23   1994.12.09          79
# Joshua Rose                  1849      GBR    18   1999.08.29          73
# Karl Kiur Saar               1849      EST    21   1996.04.21           /
# Edoardo Sardella             1849      ITA    20   1997.05.23           /
# Leo Julien Sebaoun           1849      JPN    22   1995.04.06           /
# Vazha Shubladze              1849      GEO    18   1999.09.05           /
# Vazha Shubladze              1849      GEO    18   1999.09.05           /
# ...

# %%
zapis['Starost'].plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\nanaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Starost'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-64-72f34f9b3473> in <module>()
# ----> 1 zapis['Starost'].plot()
#
# ...

# %%
zapis['Age'].plot()

zapis['Age']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\nanaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-66-d62e3babdbb4> in <module>()
# ----> 1 zapis['Age']
#
# ...

# %%
zapis('Age')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-fa26b354569b> in <module>()
# ----> 1 zapis('Age')
#
# TypeError: 'DataFrame' object is not callable

# %%
zapis = pd.read_csv(r'C:\Users\Kristjan\Documents\GitHub\ProjectTennis\podatki_za_obdelavo.txt', encoding = 'utf-8', sep=';')
zapis[-100:]
# Out:
#                              Rank Country  Age     Birthday Weight(kg)  \
# Jonathan Morr                1849     GER   19   1998.08.11          /
# David Nguyen                 1849     USA   28   1989.10.29         77
# Kody Pearson                 1849     AUS   18   1999.07.26         60
# Minhtuan Pham                1849     VIE   24   1993.10.19          /
# Greg Polmans                 1849     AUS   17   2000.01.10          /
# Nino Portales                1849     FRA   21   1996.12.28          /
# Yusuf Ebrahim Ahmed  Qaed    1849     BRN   23   1994.07.15          /
# Mauricio Resendiz            1849     MEX   23   1994.12.09         79
# Joshua Rose                  1849     GBR   18   1999.08.29         73
# Karl Kiur Saar               1849     EST   21   1996.04.21          /
# Edoardo Sardella             1849     ITA   20   1997.05.23          /
# Leo Julien Sebaoun           1849     JPN   22   1995.04.06          /
# ...

# %%
zapis = pd.read_csv(r'C:\Users\Kristjan\Documents\GitHub\ProjectTennis\podatki_za_obdelavo.txt', encoding = 'utf-8', sep=';')
zapis[-100:]
# Out:
#                              Rank Country  Age     Birthday Weight(kg)  \
# Jonathan Morr                1849     GER   19   1998.08.11          /
# David Nguyen                 1849     USA   28   1989.10.29         77
# Kody Pearson                 1849     AUS   18   1999.07.26         60
# Minhtuan Pham                1849     VIE   24   1993.10.19          /
# Greg Polmans                 1849     AUS   17   2000.01.10          /
# Nino Portales                1849     FRA   21   1996.12.28          /
# Yusuf Ebrahim Ahmed  Qaed    1849     BRN   23   1994.07.15          /
# Mauricio Resendiz            1849     MEX   23   1994.12.09         79
# Joshua Rose                  1849     GBR   18   1999.08.29         73
# Karl Kiur Saar               1849     EST   21   1996.04.21          /
# Edoardo Sardella             1849     ITA   20   1997.05.23          /
# Leo Julien Sebaoun           1849     JPN   22   1995.04.06          /
# ...

# %%
zapis = pd.read_csv(r'C:\Users\Kristjan\Documents\GitHub\ProjectTennis\podatki_za_obdelavo.txt', encoding = 'utf-8', sep=';')
zapis[-100:]
# Out:
#                              Rank Country  Age     Birthday Weight(kg)  \
# Jonathan Morr                1849     GER   19   1998.08.11          /
# David Nguyen                 1849     USA   28   1989.10.29         77
# Kody Pearson                 1849     AUS   18   1999.07.26         60
# Minhtuan Pham                1849     VIE   24   1993.10.19          /
# Greg Polmans                 1849     AUS   17   2000.01.10          /
# Nino Portales                1849     FRA   21   1996.12.28          /
# Yusuf Ebrahim Ahmed  Qaed    1849     BRN   23   1994.07.15          /
# Mauricio Resendiz            1849     MEX   23   1994.12.09         79
# Joshua Rose                  1849     GBR   18   1999.08.29         73
# Karl Kiur Saar               1849     EST   21   1996.04.21          /
# Edoardo Sardella             1849     ITA   20   1997.05.23          /
# Leo Julien Sebaoun           1849     JPN   22   1995.04.06          /
# ...

# %%
zapis['Age']
# Out:
# Rafael Nadal               31
# Roger Federer              36
# Grigor Dimitrov            26
# Alexander Zverev           20
# Dominic Thiem              24
# Marin Cilic                29
# David Goffin               27
# Jack Sock                  25
# Stan Wawrinka              32
# Pablo Carreno Busta        26
# Juan Martin del Potro      29
# Novak Djokovic             30
# Sam Querrey                30
# Kevin Anderson             31
# Jo-Wilfried Tsonga         32
# Andy Murray                30
# John Isner                 32
# Lucas Pouille              23
# Tomas Berdych              32
# Roberto Bautista Agut      29
# Nick Kyrgios               22
# Kei Nishikori              27
# Albert Ramos-Vinolas       29
# Milos Raonic               27
# Gilles Muller              34
# Diego Schwartzman          25
# Fabio Fognini              30
# Adrian Mannarino           29
# Philipp Kohlschreiber      34
# Damir Dzumhur              25
#                            ..
# ...

# %%
zapis['Age'].plot()

# %%
zapis['Age'][:100].plot()

# %%
podatki
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-75-7508797a11b9> in <module>()
# ----> 1 podatki
#
# NameError: name 'podatki' is not defined
